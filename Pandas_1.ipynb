# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
#1. Get the Metadata from the above files

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
#1. Get the Metadata from the above files

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# memory usage: 18.8+ MB

# %%
#2. Get the row names from the above files.

index_df =df.index.values
index_df2 =df1.index.values
print(index_df)
print(index_df2)
# Out:
# [   0    1    2 ... 4653 4654 4655]
# [     0      1      2 ... 117205 117206 117207]

# %%
#3. Change the column name from any of the above file.

df.rename(columns={'Indicator':'Indicator_id'}) #use of inplace will make changes permanent
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#4. Change the column name from any of the above file and store the changes made permanently.

df.rename(columns={'Indicator':'Indicator_id'},inplace=True)
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.columns
# Out:
# Index(['Indicator_id', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
#5. Change the names of multiple columns.

df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace=True)
df.head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#6. Arrange values of a particular column in ascending order.

df.sort_values(by='Year',ascending=True).head(5)
# Out:
#                            Indicator_id Publication Status  Year WHO Region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# 0        77.0  NaN   NaN       NaN
# 1270     72.0  NaN   NaN       NaN
# 3193     65.0  NaN   NaN       NaN
# 3194     68.0  NaN   NaN       NaN
# 3197     15.0  NaN   NaN       NaN

# %%
#7. Arrange multiple column values in ascending order.

df.sort_values(['Sex','Display Value','World Bank income group'],ascending=[1,1,1]).head(3)
# Out:
#                            Indicator_id Publication Status  Year WHO Region  \
# 3071  Life expectancy at age 60 (years)          Published  1990     Africa
# 3072  Life expectancy at age 60 (years)          Published  2000     Africa
# 577   Life expectancy at age 60 (years)          Published  1990     Africa
#
#      World Bank income group       Country         Sex  Display Value  \
# 3071              Low-income  Sierra Leone  Both sexes             11
# 3072              Low-income  Sierra Leone  Both sexes             11
# 577               Low-income       Eritrea  Both sexes             12
#
#       Numeric  Low  High  Comments
# 3071     11.0  NaN   NaN       NaN
# 3072     11.0  NaN   NaN       NaN
# 577      12.0  NaN   NaN       NaN

# %%
df[['Indicator_id','Country','Year','WHO Region','Publication Status']].head(3)
# Out:
#                         Indicator_id  Country  Year WHO Region  \
# 0   Life expectancy at birth (years)  Andorra  1990     Europe
# 1   Life expectancy at birth (years)  Andorra  2000     Europe
# 2  Life expectancy at age 60 (years)  Andorra  2012     Europe
#
#   Publication Status
# 0          Published
# 1          Published
# 2          Published

# %%
#8. Make 'Country' as the first column of the dataframe.

t = df['Country'].values
df.drop(['Country'],axis = 1,inplace =True)
df.insert(loc = 0 ,column='Country',value=t)
df.head(5)
# Out:
#                 Country                       Indicator_id Publication Status  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# 0             77     77.0  NaN   NaN       NaN
# 1             80     80.0  NaN   NaN       NaN
# 2             28     28.0  NaN   NaN       NaN
# 3             23     23.0  NaN   NaN       NaN
# 4             78     78.0  NaN   NaN       NaN

# %%
#9. Get the column array using a variable ('WHO Region')

who_region = df['WHO Region'].values
who_region
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
#10. Get the subset rows 11, 24, 37

df.loc[[11,24,37]]
#or
#df.iloc[[11,24,37]]
# Out:
#               Country                       Indicator_id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %%
#11. Get the subset rows excluding 5, 12, 23, and 56

not_in = df.index.isin([5,12,23,56])
df[~not_in].head(54)
# Out:
#                  Country                       Indicator_id  \
# 0                Andorra   Life expectancy at birth (years)
# 1                Andorra   Life expectancy at birth (years)
# 2                Andorra  Life expectancy at age 60 (years)
# 3                Andorra  Life expectancy at age 60 (years)
# 4   United Arab Emirates   Life expectancy at birth (years)
# 6    Antigua and Barbuda  Life expectancy at age 60 (years)
# 7    Antigua and Barbuda  Life expectancy at age 60 (years)
# 8              Australia   Life expectancy at birth (years)
# 9              Australia   Life expectancy at birth (years)
# 10             Australia   Life expectancy at birth (years)
# 11               Austria   Life expectancy at birth (years)
# 13               Belgium   Life expectancy at birth (years)
# 14               Bahrain   Life expectancy at birth (years)
# 15               Bahrain   Life expectancy at birth (years)
# 16               Bahrain  Life expectancy at age 60 (years)
# 17               Bahamas   Life expectancy at birth (years)
# 18               Bahamas  Life expectancy at age 60 (years)
# 19              Barbados   Life expectancy at birth (years)
# 20              Barbados  Life expectancy at age 60 (years)
# 21              Barbados  Life expectancy at age 60 (years)
# 22     Brunei Darussalam  Life expectancy at age 60 (years)
# 24     Brunei Darussalam  Life expectancy at age 60 (years)
# 25                Canada   Life expectancy at birth (years)
# 26                Canada  Life expectancy at age 60 (years)
# 27                Canada  Life expectancy at age 60 (years)
# 28           Switzerland   Life expectancy at birth (years)
# 29           Switzerland   Life expectancy at birth (years)
# 30           Switzerland  Life expectancy at age 60 (years)
# 31          Cook Islands   Life expectancy at birth (years)
# 32          Cook Islands  Life expectancy at age 60 (years)
# 33          Cook Islands  Life expectancy at age 60 (years)
# 34                Cyprus   Life expectancy at birth (years)
# 35                Cyprus   Life expectancy at birth (years)
# 36                Cyprus  Life expectancy at age 60 (years)
# 37                Cyprus  Life expectancy at age 60 (years)
# 38        Czech Republic   Life expectancy at birth (years)
# 39        Czech Republic   Life expectancy at birth (years)
# 40               Germany   Life expectancy at birth (years)
# 41               Germany  Life expectancy at age 60 (years)
# 42               Germany  Life expectancy at age 60 (years)
# 43               Denmark   Life expectancy at birth (years)
# 44               Denmark  Life expectancy at age 60 (years)
# 45               Denmark  Life expectancy at age 60 (years)
# 46               Denmark  Life expectancy at age 60 (years)
# 47               Denmark  Life expectancy at age 60 (years)
# 48                 Spain   Life expectancy at birth (years)
# 49                 Spain  Life expectancy at age 60 (years)
# 50                 Spain  Life expectancy at age 60 (years)
# 51               Estonia   Life expectancy at birth (years)
# 52               Estonia   Life expectancy at birth (years)
# 53               Estonia  Life expectancy at age 60 (years)
# 54               Estonia  Life expectancy at age 60 (years)
# 55               Estonia  Life expectancy at age 60 (years)
# 57               Finland  Life expectancy at age 60 (years)
#
#    Publication Status  Year             WHO Region World Bank income group  \
# 0           Published  1990                 Europe             High-income
# 1           Published  2000                 Europe             High-income
# 2           Published  2012                 Europe             High-income
# 3           Published  2000                 Europe             High-income
# 4           Published  2012  Eastern Mediterranean             High-income
# 6           Published  1990               Americas             High-income
# 7           Published  2012               Americas             High-income
# 8           Published  2012        Western Pacific             High-income
# 9           Published  2000        Western Pacific             High-income
# 10          Published  2012        Western Pacific             High-income
# 11          Published  2012                 Europe             High-income
# 13          Published  2012                 Europe             High-income
# 14          Published  2000  Eastern Mediterranean             High-income
# 15          Published  1990  Eastern Mediterranean             High-income
# 16          Published  1990  Eastern Mediterranean             High-income
# 17          Published  2012               Americas             High-income
# 18          Published  2000               Americas             High-income
# 19          Published  1990               Americas             High-income
# 20          Published  2012               Americas             High-income
# 21          Published  2012               Americas             High-income
# 22          Published  1990        Western Pacific             High-income
# 24          Published  2012        Western Pacific             High-income
# 25          Published  2000               Americas             High-income
# 26          Published  2000               Americas             High-income
# 27          Published  1990               Americas             High-income
# 28          Published  1990                 Europe             High-income
# 29          Published  2012                 Europe             High-income
# 30          Published  2000                 Europe             High-income
# 31          Published  2012        Western Pacific             High-income
# 32          Published  2012        Western Pacific             High-income
# 33          Published  2000        Western Pacific             High-income
# 34          Published  2000                 Europe             High-income
# 35          Published  2000                 Europe             High-income
# 36          Published  2000                 Europe             High-income
# 37          Published  2012                 Europe             High-income
# 38          Published  2012                 Europe             High-income
# 39          Published  1990                 Europe             High-income
# 40          Published  1990                 Europe             High-income
# 41          Published  1990                 Europe             High-income
# 42          Published  2000                 Europe             High-income
# 43          Published  2012                 Europe             High-income
# 44          Published  1990                 Europe             High-income
# 45          Published  2000                 Europe             High-income
# 46          Published  2000                 Europe             High-income
# 47          Published  2012                 Europe             High-income
# 48          Published  2012                 Europe             High-income
# 49          Published  2000                 Europe             High-income
# 50          Published  1990                 Europe             High-income
# 51          Published  1990                 Europe             High-income
# 52          Published  2012                 Europe             High-income
# 53          Published  2012                 Europe             High-income
# 54          Published  2000                 Europe             High-income
# 55          Published  2012                 Europe             High-income
# 57          Published  2012                 Europe             High-income
#
#            Sex  Display Value  Numeric  Low  High  Comments
# 0   Both sexes             77     77.0  NaN   NaN       NaN
# 1   Both sexes             80     80.0  NaN   NaN       NaN
# 2       Female             28     28.0  NaN   NaN       NaN
# 3   Both sexes             23     23.0  NaN   NaN       NaN
# 4       Female             78     78.0  NaN   NaN       NaN
# 6         Male             17     17.0  NaN   NaN       NaN
# 7   Both sexes             22     22.0  NaN   NaN       NaN
# 8         Male             81     81.0  NaN   NaN       NaN
# 9   Both sexes             80     80.0  NaN   NaN       NaN
# 10  Both sexes             83     83.0  NaN   NaN       NaN
# 11      Female             83     83.0  NaN   NaN       NaN
# 13      Female             83     83.0  NaN   NaN       NaN
# 14        Male             73     73.0  NaN   NaN       NaN
# 15      Female             74     74.0  NaN   NaN       NaN
# 16        Male             17     17.0  NaN   NaN       NaN
# 17        Male             72     72.0  NaN   NaN       NaN
# 18  Both sexes             21     21.0  NaN   NaN       NaN
# 19        Male             71     71.0  NaN   NaN       NaN
# 20      Female             25     25.0  NaN   NaN       NaN
# 21  Both sexes             23     23.0  NaN   NaN       NaN
# 22      Female             20     20.0  NaN   NaN       NaN
# 24      Female             21     21.0  NaN   NaN       NaN
# 25      Female             82     82.0  NaN   NaN       NaN
# 26        Male             21     21.0  NaN   NaN       NaN
# 27      Female             24     24.0  NaN   NaN       NaN
# 28        Male             74     74.0  NaN   NaN       NaN
# 29  Both sexes             83     83.0  NaN   NaN       NaN
# 30  Both sexes             23     23.0  NaN   NaN       NaN
# 31  Both sexes             76     76.0  NaN   NaN       NaN
# 32      Female             22     22.0  NaN   NaN       NaN
# 33  Both sexes             18     18.0  NaN   NaN       NaN
# 34      Female             79     79.0  NaN   NaN       NaN
# 35  Both sexes             77     77.0  NaN   NaN       NaN
# 36      Female             22     22.0  NaN   NaN       NaN
# 37      Female             26     26.0  NaN   NaN       NaN
# 38        Male             75     75.0  NaN   NaN       NaN
# 39      Female             75     75.0  NaN   NaN       NaN
# 40      Female             79     79.0  NaN   NaN       NaN
# 41        Male             18     18.0  NaN   NaN       NaN
# 42        Male             20     20.0  NaN   NaN       NaN
# 43  Both sexes             80     80.0  NaN   NaN       NaN
# 44        Male             18     18.0  NaN   NaN       NaN
# 45        Male             19     19.0  NaN   NaN       NaN
# 46  Both sexes             21     21.0  NaN   NaN       NaN
# 47  Both sexes             23     23.0  NaN   NaN       NaN
# 48  Both sexes             82     82.0  NaN   NaN       NaN
# 49      Female             25     25.0  NaN   NaN       NaN
# 50  Both sexes             22     22.0  NaN   NaN       NaN
# 51      Female             75     75.0  NaN   NaN       NaN
# 52      Female             81     81.0  NaN   NaN       NaN
# 53        Male             18     18.0  NaN   NaN       NaN
# 54      Female             21     21.0  NaN   NaN       NaN
# 55      Female             24     24.0  NaN   NaN       NaN
# 57        Male             22     22.0  NaN   NaN       NaN

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.set_index('UserID')
# Out:
#             User  Gender  Registered   Cancelled
# UserID
# 1        Charles    male  2012-12-21         NaN
# 2          Pedro    male  2010-08-01  2010-08-08
# 3       Caroline  female  2012-10-23  2016-06-07
# 4        Brielle  female  2013-07-17         NaN
# 5       Benjamin    male  2010-11-25         NaN

# %%
sessions.set_index('SessionID')
# Out:
#           SessionDate  UserID
# SessionID
# 1          2010-01-05       2
# 2          2010-08-01       2
# 3          2010-11-25       2
# 4          2011-09-21       5
# 5          2011-10-19       4
# 6          2012-10-23       4
# 7          2012-12-21       3
# 8          2013-05-22       4
# 9          2013-07-17       4
# 10         2016-01-11       4

# %%
products.set_index('ProductID')
# Out:
#           Product  Price
# ProductID
# 1               A  14.16
# 2               B  33.04
# 3               C  10.65
# 4               D  10.02
# 5               E  29.66

# %%
transactions.set_index('TransactionID')
# Out:
#               TransactionDate  UserID  ProductID  Quantity
# TransactionID
# 1                  2010-08-21     7.0          2         1
# 2                  2011-05-26     3.0          4         1
# 3                  2011-06-16     3.0          3         1
# 4                  2012-08-26     1.0          2         3
# 5                  2013-06-06     2.0          4         1
# 6                  2013-12-23     2.0          5         6
# 7                  2013-12-30     3.0          4         1
# 8                  2014-04-24     NaN          2         3
# 9                  2015-04-24     7.0          4         3
# 10                 2016-05-08     3.0          4         4

# %%
#12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

tr_left = transactions.join(other=users.set_index('UserID'),on='UserID',how='left')
tr_left
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 6  female  2012-10-23  2016-06-07
# 7     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 9  female  2012-10-23  2016-06-07

# %%
#13. Which transactions have a UserID not in users?

mapp = transactions['UserID'].isin(users['UserID'])
transactions[~mapp]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

tr_inner = transactions.join(other=users.set_index('UserID'),on='UserID',how='inner')
tr_inner
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 6              7      2013-12-30     3.0          4         1  Caroline
# 9             10      2016-05-08     3.0          4         4  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 6  female  2012-10-23  2016-06-07
# 9  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08

# %%
#15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

tr_outer = transactions.join(other=users.set_index('UserID'),on='UserID',how='outer')
tr_outer
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0            1.0      2010-08-21     7.0        2.0       1.0       NaN
# 8            9.0      2015-04-24     7.0        4.0       3.0       NaN
# 1            2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 2            3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 6            7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 9           10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 3            4.0      2012-08-26     1.0        2.0       3.0   Charles
# 4            5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 5            6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 7            8.0      2014-04-24     NaN        2.0       3.0       NaN
# 9            NaN             NaN     4.0        NaN       NaN   Brielle
# 9            NaN             NaN     5.0        NaN       NaN  Benjamin
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 6  female  2012-10-23  2016-06-07
# 9  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 7     NaN         NaN         NaN
# 9  female  2013-07-17         NaN
# 9    male  2010-11-25         NaN

# %%
#16. Determine which sessions occurred on the same day each user registered

ses_inner = sessions.join(other=users.set_index('UserID'),how='inner',on='UserID')
ses_inner[ses_inner['SessionDate'] == ses_inner['Registered']]
# Out:
#    SessionID SessionDate  UserID     User  Gender  Registered   Cancelled
# 1          2  2010-08-01       2    Pedro    male  2010-08-01  2010-08-08
# 8          9  2013-07-17       4  Brielle  female  2013-07-17         NaN

# %%
ses_inner
# Out:
#    SessionID SessionDate  UserID      User  Gender  Registered   Cancelled
# 0          1  2010-01-05       2     Pedro    male  2010-08-01  2010-08-08
# 1          2  2010-08-01       2     Pedro    male  2010-08-01  2010-08-08
# 2          3  2010-11-25       2     Pedro    male  2010-08-01  2010-08-08
# 3          4  2011-09-21       5  Benjamin    male  2010-11-25         NaN
# 4          5  2011-10-19       4   Brielle  female  2013-07-17         NaN
# 5          6  2012-10-23       4   Brielle  female  2013-07-17         NaN
# 7          8  2013-05-22       4   Brielle  female  2013-07-17         NaN
# 8          9  2013-07-17       4   Brielle  female  2013-07-17         NaN
# 9         10  2016-01-11       4   Brielle  female  2013-07-17         NaN
# 6          7  2012-12-21       3  Caroline  female  2012-10-23  2016-06-07

# %%
#17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

products['pseudo_key'] = 1
users['pseudo_key'] = 1
mg = users.merge(products,on='pseudo_key')
users.drop(['pseudo_key'],axis=1,inplace=True)
products.drop(['pseudo_key'],axis=1,inplace=True)
mg[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
#18. Determine how much quantity of each product was purchased by each user

tr_mg = pd.merge(mg, transactions, how='left', on=['UserID', 'ProductID'])
tr_mg.groupby(['UserID','ProductID'])['Quantity'].sum().reset_index()
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %%
#19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

tr_mg=transactions.merge(transactions,on='UserID')
tr_mg
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# 12                7        2013-12-30     3.0            4           1
# 13                7        2013-12-30     3.0            4           1
# 14                7        2013-12-30     3.0            4           1
# 15                7        2013-12-30     3.0            4           1
# 16               10        2016-05-08     3.0            4           4
# 17               10        2016-05-08     3.0            4           4
# 18               10        2016-05-08     3.0            4           4
# 19               10        2016-05-08     3.0            4           4
# 20                4        2012-08-26     1.0            2           3
# 21                5        2013-06-06     2.0            4           1
# 22                5        2013-06-06     2.0            4           1
# 23                6        2013-12-23     2.0            5           6
# 24                6        2013-12-23     2.0            5           6
# 25                8        2014-04-24     NaN            2           3
#
#     TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                 1        2010-08-21            2           1
# 1                 9        2015-04-24            4           3
# 2                 1        2010-08-21            2           1
# 3                 9        2015-04-24            4           3
# 4                 2        2011-05-26            4           1
# 5                 3        2011-06-16            3           1
# 6                 7        2013-12-30            4           1
# 7                10        2016-05-08            4           4
# 8                 2        2011-05-26            4           1
# 9                 3        2011-06-16            3           1
# 10                7        2013-12-30            4           1
# 11               10        2016-05-08            4           4
# 12                2        2011-05-26            4           1
# 13                3        2011-06-16            3           1
# 14                7        2013-12-30            4           1
# 15               10        2016-05-08            4           4
# 16                2        2011-05-26            4           1
# 17                3        2011-06-16            3           1
# 18                7        2013-12-30            4           1
# 19               10        2016-05-08            4           4
# 20                4        2012-08-26            2           3
# 21                5        2013-06-06            4           1
# 22                6        2013-12-23            5           6
# 23                5        2013-06-06            4           1
# 24                6        2013-12-23            5           6
# 25                8        2014-04-24            2           3

# %%
#20. Join each user to his/her first occuring transaction in the transactions table

ft_tr = transactions.groupby('UserID').first()
ft_us = users.join(other=ft_tr,on='UserID',how='left')
ft_us
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %% [markdown]
# 21. Test to see if we can drop columns
#
# my_columns -> ['UserID','User','Gender','Registered','Cancelled','TransactionID','TransactionDate','ProductID','Quantity']
#
# Output: Count of missing data
#
# number missing for column Cancelled: 3
#
# number missing for column TransactionID: 2
#
# number missing for column TransactionDate: 2
#
# number missing for column ProductID: 2
#
# number missing for column Quantity: 2
#
#
# Output of percentage missing datapercent missing for column Cancelled: 0.6
#
# percent missing for column TransactionID: 0.4
#
# percent missing for column TransactionDate: 0.4
#
# percent missing for column ProductID: 0.4
#
# percent missing for column Quantity: 0.4

# %%
#21 Answer
data = users.join(transactions.groupby('UserID').first(),on='UserID')

# %%
#data = tr_outer
my_columns = list(data.columns)
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    percent_missing = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4

# %%
data
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %% [markdown]
# Please see question 7 and  In [10], In [11] of this notebook.I have tried all possible columns to sort(In [10])  but output is
# got by subsetting the columns(In [11])
#
# Please see question 21 ("in question pdf") It has given code and output i am not able to understand what to do in the question.
# But i tried to solve it pls rectify my doubts.
#
# thanks in advance
